# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19095    -122.61     38.24                18.0       2933.0           481.0
# 10502    -117.70     33.47                21.0       2208.0           534.0
# 16519    -121.21     37.80                45.0        370.0            84.0
# 19451    -121.02     37.68                28.0       2875.0           560.0
# 730      -122.13     37.68                45.0       2457.0           445.0
# ...          ...       ...                 ...          ...             ...
# 11992    -117.51     33.97                35.0        352.0            62.0
# 2105     -119.76     36.75                39.0       2233.0           563.0
# 12793    -121.45     38.64                23.0       1481.0           343.0
# 9997     -121.05     39.11                 7.0       2767.0           423.0
# 14740    -117.05     32.58                22.0       2101.0           399.0
#
#        population  households  median_income ocean_proximity  \
# 19095      1279.0       443.0         5.0849       <1H OCEAN
# 10502      1423.0       482.0         3.5915       <1H OCEAN
# 16519       167.0        70.0         1.4853          INLAND
# 19451      1608.0       558.0         3.5489          INLAND
# 730        1129.0       422.0         4.0588        NEAR BAY
# ...           ...         ...            ...             ...
# 11992       184.0        57.0         3.6691          INLAND
# 2105       2031.0       491.0         1.8641          INLAND
# 12793      1079.0       315.0         1.8670          INLAND
# 9997       1143.0       382.0         3.6333          INLAND
# 14740      1551.0       371.0         4.1518      NEAR OCEAN
#
#        median_house_value
# 19095            188500.0
# 10502            305600.0
# 16519            101800.0
# 19451            106400.0
# 730              182800.0
# ...                   ...
# 11992            137500.0
# 2105              50800.0
# 12793             60600.0
# 9997             170200.0
# 14740            136900.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.loc[:, train_data.columns!='ocean_proximity'].corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19095    -122.61     38.24                18.0     7.984122        6.177944
# 10502    -117.70     33.47                21.0     7.700295        6.282267
# 16519    -121.21     37.80                45.0     5.916202        4.442651
# 19451    -121.02     37.68                28.0     7.964156        6.329721
# 730      -122.13     37.68                45.0     7.807103        6.100319
# ...          ...       ...                 ...          ...             ...
# 11992    -117.51     33.97                35.0     5.866468        4.143135
# 2105     -119.76     36.75                39.0     7.711549        6.335054
# 12793    -121.45     38.64                23.0     7.301148        5.840642
# 9997     -121.05     39.11                 7.0     7.925880        6.049733
# 14740    -117.05     32.58                22.0     7.650645        5.991465
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19095    7.154615    6.095825         5.0849            188500.0       True
# 10502    7.261225    6.180017         3.5915            305600.0       True
# 16519    5.123964    4.262680         1.4853            101800.0      False
# 19451    7.383368    6.326149         3.5489            106400.0      False
# 730      7.029973    6.047372         4.0588            182800.0      False
# ...           ...         ...            ...                 ...        ...
# 11992    5.220356    4.060443         3.6691            137500.0      False
# 2105     7.616776    6.198479         1.8641             50800.0      False
# 12793    6.984716    5.755742         1.8670             60600.0      False
# 9997     7.042286    5.948035         3.6333            170200.0      False
# 14740    7.347300    5.918894         4.1518            136900.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 19095   False   False     False       False       0.773779         1.309769
# 10502   False   False     False       False       0.815848         1.245999
# 16519    True   False     False       False       0.750930         1.387907
# 19451    True   False     False       False       0.794776         1.258926
# 730     False   False      True       False       0.781381         1.290991
# ...       ...     ...       ...         ...            ...              ...
# 11992    True   False     False       False       0.706240         1.444785
# 2105     True   False     False       False       0.821502         1.244103
# 12793    True   False     False       False       0.799962         1.268498
# 9997     True   False     False       False       0.763289         1.332521
# 14740   False   False     False        True       0.783132         1.292580
#
# [16346 rows x 16 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x="latitude", y="longitude", data = train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19095    -122.61     38.24                18.0     7.984122        6.177944
# 10502    -117.70     33.47                21.0     7.700295        6.282267
# 16519    -121.21     37.80                45.0     5.916202        4.442651
# 19451    -121.02     37.68                28.0     7.964156        6.329721
# 730      -122.13     37.68                45.0     7.807103        6.100319
# ...          ...       ...                 ...          ...             ...
# 11992    -117.51     33.97                35.0     5.866468        4.143135
# 2105     -119.76     36.75                39.0     7.711549        6.335054
# 12793    -121.45     38.64                23.0     7.301148        5.840642
# 9997     -121.05     39.11                 7.0     7.925880        6.049733
# 14740    -117.05     32.58                22.0     7.650645        5.991465
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 19095    7.154615    6.095825         5.0849            188500.0       True
# 10502    7.261225    6.180017         3.5915            305600.0       True
# 16519    5.123964    4.262680         1.4853            101800.0      False
# 19451    7.383368    6.326149         3.5489            106400.0      False
# 730      7.029973    6.047372         4.0588            182800.0      False
# ...           ...         ...            ...                 ...        ...
# 11992    5.220356    4.060443         3.6691            137500.0      False
# 2105     7.616776    6.198479         1.8641             50800.0      False
# 12793    6.984716    5.755742         1.8670             60600.0      False
# 9997     7.042286    5.948035         3.6333            170200.0      False
# 14740    7.347300    5.918894         4.1518            136900.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 19095   False   False     False       False       0.773779         1.309769
# 10502   False   False     False       False       0.815848         1.245999
# 16519    True   False     False       False       0.750930         1.387907
# 19451    True   False     False       False       0.794776         1.258926
# 730     False   False      True       False       0.781381         1.290991
# ...       ...     ...       ...         ...            ...              ...
# 11992    True   False     False       False       0.706240         1.444785
# 2105     True   False     False       False       0.821502         1.244103
# 12793    True   False     False       False       0.799962         1.268498
# 9997     True   False     False       False       0.763289         1.332521
# 14740   False   False     False        True       0.783132         1.292580
#
# [16346 rows x 16 columns]

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_47160\1859659485.py in ?()
#       4 test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
#       5 test_data['population'] = np.log(test_data['population'] + 1)
#       6 test_data['households'] = np.log(test_data['households'] + 1)
#       7
# ----> 8 test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)
#       9
#      10 test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
#      11 test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9513     -123.21     39.14                39.0     2.111232        1.882842
# 14832    -117.09     32.67                31.0     2.154847        1.989232
# 536      -122.28     37.79                30.0     2.233224        2.050076
# 19624    -121.01     37.37                41.0     2.073515        1.864905
# 10087    -117.97     33.94                36.0     2.144085        1.920739
# ...          ...       ...                 ...          ...             ...
# 20311    -119.11     34.17                37.0     1.967792        1.734031
# 15538    -117.10     33.12                12.0     2.062933        1.922456
# 9598     -120.48     37.31                42.0     2.171025        1.979659
# 16169    -122.55     37.79                32.0     2.159271        2.006784
# 7289     -118.22     33.98                32.0     2.183807        2.028667
#
#        population  households  median_income  <1H OCEAN  INLAND  NEAR BAY  \
# 9513     2.014272    1.891788         3.0000       True   False     False
# 14832    2.124229    1.986465         2.0520      False   False     False
# 536      2.220037    2.047986         2.5444      False   False      True
# 19624    2.008277    1.862904         2.3583      False    True     False
# 10087    2.061068    1.914541         4.1205       True   False     False
# ...           ...         ...            ...        ...     ...       ...
# 20311    1.982322    1.692090         2.0368      False   False     False
# 15538    1.910393    1.841861         0.8130       True   False     False
# 9598     2.131740    1.979390         2.3550      False    True     False
# 16169    2.093686    1.994821         2.9201      False   False     False
# 7289     2.189641    2.023939         2.5352       True   False     False
#
#        NEAR OCEAN  bedroom_ratio  household_rooms  median_house_value
# 9513        False       0.891821         1.115999            114600.0
# 14832        True       0.923143         1.084765            108900.0
# 536         False       0.917989         1.090449            275000.0
# 19624       False       0.899393         1.113055             95000.0
# 10087       False       0.895832         1.119895            217000.0
# ...           ...            ...              ...                 ...
# 20311        True       0.881207         1.162936            243800.0
# 15538       False       0.931904         1.120026            275000.0
# 9598        False       0.911855         1.096815             75600.0
# 16169        True       0.929380         1.082438            322200.0
# 7289        False       0.928959         1.078988            184400.0
#
# [4087 rows x 15 columns]

# %%
X_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
X_test_s = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 X_test_s = scaler.transform(X_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_data.py:1006, in StandardScaler.transform(self, X, copy)
#    1003 check_is_fitted(self)
#    1005 copy = copy if copy is not None else self.copy
# -> 1006 X = self._validate_data(
#    1007     X,
#    1008     reset=False,
#    1009     accept_sparse="csr",
#    1010     copy=copy,
#    1011     dtype=FLOAT_DTYPES,
#    1012     force_all_finite="allow-nan",
#    1013 )
#    1015 if sparse.issparse(X):
#    1016     if self.with_mean:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     509 def _validate_data(
#     510     self,
#     511     X="no_validation",
#    (...)
#     516     **check_params,
#     517 ):
#     518     """Validate input data and set or check the `n_features_in_` attribute.
#     519
#     520     Parameters
#    (...)
#     578         validated.
#     579     """
# --> 580     self._check_feature_names(X, reset=reset)
#     582     if y is None and self._get_tags()["requires_y"]:
#     583         raise ValueError(
#     584             f"This {self.__class__.__name__} estimator "
#     585             "requires y to be passed, but the target y is None."
#     586         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:507, in BaseEstimator._check_feature_names(self, X, reset)
#     502 if not missing_names and not unexpected_names:
#     503     message += (
#     504         "Feature names must be in the same order as they were in fit.\n"
#     505     )
# --> 507 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - ISLAND

# %%
reg.score(X_test_s, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 reg.score(X_test_s, y_test)
#
# NameError: name 'X_test_s' is not defined

# %%
reg.score(X_test_s, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 reg.score(X_test_s, y_test)
#
# NameError: name 'X_test_s' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 forest.score(X_test, y_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:760, in RegressorMixin.score(self, X, y, sample_weight)
#     718 """Return the coefficient of determination of the prediction.
#     719
#     720 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     755 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     756 """
#     758 from .metrics import r2_score
# --> 760 y_pred = self.predict(X)
#     761 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:984, in ForestRegressor.predict(self, X)
#     982 check_is_fitted(self)
#     983 # Check data
# --> 984 X = self._validate_X_predict(X)
#     986 # Assign chunk of trees to jobs
#     987 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:599, in BaseForest._validate_X_predict(self, X)
#     596 """
#     597 Validate X whenever one tries to predict, apply, predict_proba."""
#     598 check_is_fitted(self)
# --> 599 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     600 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     601     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     509 def _validate_data(
#     510     self,
#     511     X="no_validation",
#    (...)
#     516     **check_params,
#     517 ):
#     518     """Validate input data and set or check the `n_features_in_` attribute.
#     519
#     520     Parameters
#    (...)
#     578         validated.
#     579     """
# --> 580     self._check_feature_names(X, reset=reset)
#     582     if y is None and self._get_tags()["requires_y"]:
#     583         raise ValueError(
#     584             f"This {self.__class__.__name__} estimator "
#     585             "requires y to be passed, but the target y is None."
#     586         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:507, in BaseEstimator._check_feature_names(self, X, reset)
#     502 if not missing_names and not unexpected_names:
#     503     message += (
#     504         "Feature names must be in the same order as they were in fit.\n"
#     505     )
# --> 507 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - ISLAND

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [3, 10, 30],
    "max_features": [2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring="neg_mean_squared_error",
                           return_train_score=True)

grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 best_forest.score(X_test_s, y_test)
#
# NameError: name 'X_test_s' is not defined
